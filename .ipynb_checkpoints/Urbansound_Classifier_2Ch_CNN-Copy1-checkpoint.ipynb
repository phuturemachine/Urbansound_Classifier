# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction-and-dataset-exploration" data-toc-modified-id="Introduction-and-dataset-exploration-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction and dataset exploration</a></span><ul class="toc-item"><li><span><a href="#Import-Packages" data-toc-modified-id="Import-Packages-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Import Packages</a></span></li><li><span><a href="#Explore-data" data-toc-modified-id="Explore-data-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Explore data</a></span></li><li><span><a href="#Prepare-working-dataset" data-toc-modified-id="Prepare-working-dataset-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Prepare working dataset</a></span></li></ul></li><li><span><a href="#Create-the-Convolutional-Neural-Network" data-toc-modified-id="Create-the-Convolutional-Neural-Network-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Create the Convolutional Neural Network</a></span><ul class="toc-item"><li><span><a href="#Import-packages" data-toc-modified-id="Import-packages-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Import packages</a></span></li><li><span><a href="#Build-the-Model" data-toc-modified-id="Build-the-Model-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Build the Model</a></span></li></ul></li><li><span><a href="#Train-and-Evaluate-the-model" data-toc-modified-id="Train-and-Evaluate-the-model-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Train and Evaluate the model</a></span><ul class="toc-item"><li><span><a href="#Create-Train-and-Validation-Dataset" data-toc-modified-id="Create-Train-and-Validation-Dataset-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Create Train and Validation Dataset</a></span></li><li><span><a href="#Create-Train-function" data-toc-modified-id="Create-Train-function-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Create Train function</a></span></li></ul></li><li><span><a href="#Train-and-Evaluate-the-Model" data-toc-modified-id="Train-and-Evaluate-the-Model-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Train and Evaluate the Model</a></span><ul class="toc-item"><li><span><a href="#Tensorflow-configuration-for-GPU" data-toc-modified-id="Tensorflow-configuration-for-GPU-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Tensorflow configuration for GPU</a></span></li><li><span><a href="#Plot-Function" data-toc-modified-id="Plot-Function-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Plot Function</a></span></li><li><span><a href="#Training,-Validation-and-Testing-using-10-fold" data-toc-modified-id="Training,-Validation-and-Testing-using-10-fold-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Training, Validation and Testing using 10 fold</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Introduction and dataset exploration

# %% [markdown]
# __Urban Sound Audio Classification __
#
# https://urbansounddataset.weebly.com/urbansound8k.html
#
# __Dataset Description__
#
# This dataset contains 8732 labeled sound excerpts (<=4s) of urban sounds from 10 classes: air_conditioner, car_horn, children_playing, dog_bark, drilling, enginge_idling, gun_shot, jackhammer, siren, and street_music. The classes are drawn from the urban sound taxonomy. For a detailed description of the dataset and how it was compiled please refer to our paper.
# All excerpts are taken from field recordings uploaded to www.freesound.org. The files are pre-sorted into ten folds (folders named fold1-fold10) to help in the reproduction of and comparison with the automatic classification results reported in the article above.
#
# __Audio Files Included__
#
# 8732 audio files of urban sounds (see description above) in WAV format. The sampling rate, bit depth, and number of channels are the same as those of the original file uploaded to Freesound (and hence may vary from file to file).
#
# __Meta-data Files Included__
#
# UrbanSound8k.csv
#
# This file contains meta-data information about every audio file in the dataset. This includes:
#
# * slice_file_name:
# The name of the audio file. The name takes the following format: [fsID]-[classID]-[occurrenceID]-[sliceID].wav, where:
# [fsID] = the Freesound ID of the recording from which this excerpt (slice) is taken
# [classID] = a numeric identifier of the sound class (see description of classID below for further details)
# [occurrenceID] = a numeric identifier to distinguish different occurrences of the sound within the original recording
# [sliceID] = a numeric identifier to distinguish different slices taken from the same occurrence
#
# * fsID:
# The Freesound ID of the recording from which this excerpt (slice) is taken
#
# * start
# The start time of the slice in the original Freesound recording
#
# * end:
# The end time of slice in the original Freesound recording
#
# * salience:
# A (subjective) salience rating of the sound. 1 = foreground, 2 = background.
#
# * fold:
# The fold number (1-10) to which this file has been allocated.
#
# * classID:
#
# A numeric identifier of the sound class:
#
# 0 = air_conditioner
#
# 1 = car_horn
#
# 2 = children_playing
#
# 3 = dog_bark
#
# 4 = drilling
#
# 5 = engine_idling
#
# 6 = gun_shot
#
# 7 = jackhammer
#
# 8 = siren
#
# 9 = street_music
#
# * class:
# The class name: air_conditioner, car_horn, children_playing, dog_bark, drilling, engine_idling, gun_shot, jackhammer,
# siren, street_music.

# %% [markdown]
# ## Import Packages

# %%
import IPython
import IPython.display as ipd
import librosa
import librosa.display
import os
import os.path
import pandas as pd
import numpy as np
import glob 
import matplotlib.pyplot as plt
import json
import random

#%pylab inline
# %matplotlib inline

# %% [markdown]
# ## Explore data

# %% [markdown]
# Listen to one dataset sample example:

# %%
ipd.Audio('./UrbanSound8K/audio/fold1/7061-6-0-0.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Load and plot the audio file in the notebook using librosa. the output of librosa.load() is a numpy array with the audio data and the corrisponding sample rate

# %%
#load data
audiofile, sr = librosa.load('./UrbanSound8K/audio/fold1/7061-6-0-0.wav')

#plot
plt.figure(figsize=(12, 4))
librosa.display.waveplot(audiofile, sr=sr)

# %% [markdown]
# Plot 4 random samples from trainset to have a first figure of different classes waveform shapes, envelopes..

# %% [markdown]
# ## Prepare working dataset

# %% [markdown]
# Steps
#
# 1) Load metadata from the given .csv file into a pandas dataframe
#
# 2) Compute features calculation for each sample
#
# 3) Create another pandas dataframe with features and the file name associated with
#
# 4) Merge the two pandas dataframes matching rows with same file name

# %%
#step 1
# load sample ids and labels from csv for test and train datasets
metadata_df = pd.read_csv('./UrbanSound8K/metadata/UrbanSound8K.csv')
del metadata_df['fsID']
metadata_df['duration']=metadata_df['end'].sub(metadata_df['start'], axis=0)
del metadata_df['start']
del metadata_df['end']
del metadata_df['salience']
metadata_df
# Out:
#          slice_file_name  fold  classID             class  duration
# 0       100032-3-0-0.wav     5        3          dog_bark  0.317551
# 1     100263-2-0-117.wav     5        2  children_playing  4.000000
# 2     100263-2-0-121.wav     5        2  children_playing  4.000000
# 3     100263-2-0-126.wav     5        2  children_playing  4.000000
# 4     100263-2-0-137.wav     5        2  children_playing  4.000000
# ...                  ...   ...      ...               ...       ...
# 8727     99812-1-2-0.wav     7        1          car_horn  4.000000
# 8728     99812-1-3-0.wav     7        1          car_horn  2.142545
# 8729     99812-1-4-0.wav     7        1          car_horn  3.505983
# 8730     99812-1-5-0.wav     7        1          car_horn  2.532098
# 8731     99812-1-6-0.wav     7        1          car_horn  2.532099
#
# [8732 rows x 5 columns]

# %%
metadata_df.describe()
# Out:
#               fold      classID     duration
# count  8732.000000  8732.000000  8732.000000
# mean      5.385937     4.592877     3.607904
# std       2.846820     2.894544     0.973570
# min       1.000000     0.000000     0.054517
# 25%       3.000000     2.000000     4.000000
# 50%       5.000000     4.000000     4.000000
# 75%       8.000000     7.000000     4.000000
# max      10.000000     9.000000     4.000000

# %%
###### Step 2 & 3: Compute MFCCs coefficient
# Create pandas dataframe for ease of matching with metadata_df, save it also to json file

Tot_bins = int(22050 * 4) #4 seconds long signals 

sr = 22050
n_mfcc=40
n_fft=2048
hop_length=512
fmin=librosa.midi_to_hz(36)

features = {"MELSPEC": [], "CHROMA":[],"file_name": []}

dataset_path= './UrbanSound8K/audio/'
json_path = "./UrbanSound8K/metadata/extracted_features_2Ch.json"

"""
since feature extraction might take a while, 
it is better to save results in a json file.
the following if/else statements simply check if this calculation has already been made,
and simply load last computed data from the relative json file
"""

if os.path.isfile(json_path):
    with open(json_path, "r") as fp:
        data = json.load(fp)
        features["MELSPEC"] = data["MELSPEC"]
        features["CHROMA"] = data["CHROMA"]
        
        for i in range(len(data["file_name"])):
            data["file_name"][i] = data["file_name"][i].split("/")[-1]
        
        features["file_name"] = data["file_name"]
        
    features_df = pd.DataFrame(features)
    
else:
    # WARNING --> This might take a while, plenty of mfccs calculation 
    
    for (dirpath, dirnames, filenames) in os.walk(dataset_path):
        # ensure we're at sub-folder level
        if dirpath is not dataset_path:
        # process all audio files in sub-dir and store MFCCs
            for f in filenames:
                file_path = os.path.join(dirpath, f)
                if file_path.endswith('.wav'):
                    
                    # load audio file and slice it to ensure length consistency among different files
                    
                    signal, sample_rate = librosa.load(file_path)
                    signal2 = np.array([float(0)]*Tot_bins)
                    # adjust signal length
                    if len(signal) >= Tot_bins:
                        # ensure consistency of the length of the signal
                        signal = signal[:Tot_bins]
                    elif len(signal) < Tot_bins:
                        len_ratio = int(Tot_bins/len(signal))
                        signal2[:len_ratio*len(signal)] = np.array(signal.tolist()*len_ratio) #duplicate signal copy as many time as possible  among the chosen length
                        signal = signal2
                        
                    # extract MFCCs, Chroma
                    MELSPEC = librosa.feature.melspectrogram(signal, sr = sr,  n_mels= n_mfcc, n_fft= n_fft, hop_length=hop_length)
                    CHROMA = librosa.feature.chroma_cqt(signal, sr=sr, fmin=fmin, n_chroma =  n_mfcc, hop_length = hop_length)
                    
                    
                    
                    # store data for analysed track
                    features["MELSPEC"].append(MELSPEC.T.tolist())
                    features["CHROMA"].append(CHROMA.T.tolist())
                    features["file_name"].append(file_path.split("/")[-1])

    features_df = pd.DataFrame(features)
    # save data in json file
    with open(json_path, "w") as fp:
        json.dump(features, fp, indent=4)
    
           
print(f'The number of keys for the features dictionary is: {len(features)}')
print(f'For each key the corresponding number of samples is: {len(features_df["MELSPEC"])}')
print(f'For each .wav sample the number of hop/time windows considered for Melspectrogram and CHROMA are: {len(features_df["MELSPEC"][0])}')
  

features_df
# Out:
# The number of keys for the features dictionary is: 3
# For each key the corresponding number of samples is: 8732
# For each .wav sample the number of hop/time windows considered for Melspectrogram and CHROMA are: 173
#                                                 MELSPEC  \
# 0     [[1.3251057863235474, 0.6968226432800293, 0.34...
# 1     [[0.0005093246581964195, 0.0010934759629890323...
# 2     [[0.005520933773368597, 0.0003163853834848851,...
# 3     [[4.059558391571045, 11.552474021911621, 4.243...
# 4     [[1.587707281112671, 0.348023384809494, 0.1081...
# ...                                                 ...
# 8727  [[17.985422134399414, 5.164201259613037, 0.074...
# 8728  [[0.42345502972602844, 0.24279381334781647, 0....
# 8729  [[0.059156183153390884, 0.39165017008781433, 0...
# 8730  [[5.534974098205566, 0.25385865569114685, 0.01...
# 8731  [[0.004053979180753231, 0.0037200222723186016,...
#
#                                                  CHROMA          file_name
# 0     [[0.7859858778391681, 0.572258000474033, 0.309...    24728-7-4-0.wav
# 1     [[0.39570057907006656, 0.339877252181454, 0.54...   161129-4-0-9.wav
# 2     [[0.6401414126716668, 0.41541352021838907, 0.4...   174873-3-5-1.wav
# 3     [[0.13014341711970362, 0.12902273625999452, 0....  113202-5-0-20.wav
# 4     [[0.1910132447152643, 0.2760164093103374, 0.37...   113203-5-0-0.wav
# ...                                                 ...                ...
# 8727  [[0.20725595479188558, 0.2231165281255829, 0.1...   165644-4-0-1.wav
# 8728  [[0.5303467085166118, 0.45036766216855234, 0.5...   102853-8-1-0.wav
# 8729  [[0.5295180971103433, 0.39349880529475384, 0.2...    49313-2-0-4.wav
# 8730  [[0.3186869809050146, 0.5271554188889589, 0.38...   165529-2-0-6.wav
# 8731  [[0.3719785788863026, 0.43742436081504216, 0.5...    67049-3-0-0.wav
#
# [8732 rows x 3 columns]

# %%
# Step 4: Merge DataFrames
metadata_df.rename(columns={'slice_file_name': 'file_name'}, inplace=True)
complete_df = pd.merge(metadata_df, features_df, on='file_name',how='inner')

#free some memory
del features
del features_df
del metadata_df

complete_df
# Out:
#                file_name  fold  classID             class  duration  \
# 0       100032-3-0-0.wav     5        3          dog_bark  0.317551
# 1     100263-2-0-117.wav     5        2  children_playing  4.000000
# 2     100263-2-0-121.wav     5        2  children_playing  4.000000
# 3     100263-2-0-126.wav     5        2  children_playing  4.000000
# 4     100263-2-0-137.wav     5        2  children_playing  4.000000
# ...                  ...   ...      ...               ...       ...
# 8727     99812-1-2-0.wav     7        1          car_horn  4.000000
# 8728     99812-1-3-0.wav     7        1          car_horn  2.142545
# 8729     99812-1-4-0.wav     7        1          car_horn  3.505983
# 8730     99812-1-5-0.wav     7        1          car_horn  2.532098
# 8731     99812-1-6-0.wav     7        1          car_horn  2.532099
#
#                                                 MELSPEC  \
# 0     [[0.0002349094720557332, 0.0002592545060906559...
# 1     [[0.016555849462747574, 0.003700889414176345, ...
# 2     [[0.025222621858119965, 0.008002770133316517, ...
# 3     [[0.05556589365005493, 0.00316132721491158, 0....
# 4     [[0.03578554466366768, 0.019973646849393845, 0...
# ...                                                 ...
# 8727  [[0.00742676854133606, 0.006138121243566275, 0...
# 8728  [[0.033585529774427414, 0.0025470342952758074,...
# 8729  [[0.06602473556995392, 0.5803515911102295, 0.3...
# 8730  [[0.022997304797172546, 0.018437596037983894, ...
# 8731  [[0.24809792637825012, 0.33949023485183716, 0....
#
#                                                  CHROMA
# 0     [[1.0, 0.14234458683608062, 0.5243197807881116...
# 1     [[0.36808137864178087, 0.7154549207553783, 0.5...
# 2     [[0.4155136947811864, 0.8303363475699852, 0.57...
# 3     [[0.5689651555847601, 0.18268903440112905, 0.7...
# 4     [[0.45380236504852434, 0.45601067619029445, 0....
# ...                                                 ...
# 8727  [[0.8370464130969233, 0.6024189082024787, 0.37...
# 8728  [[0.5398171278066045, 0.7449437098691126, 0.97...
# 8729  [[0.2311138869229023, 0.2386982204777027, 0.18...
# 8730  [[0.44503199040804975, 0.4557827025162944, 0.6...
# 8731  [[0.5902464103071948, 0.9317957391863625, 0.87...
#
# [8732 rows x 7 columns]

# %% [markdown]
# __further data exploration__
#
# Plot 4 random waveforms and corresponding mel-spectrum from the dataset indicating class

# %%
## initialize figure for plotting
fig = plt.figure(figsize=(15, 40))

#select 4 random index from train dataset available indexes           
for p in range(4):
    
    
    i=random.randint(0, 8731)
    
    audio_name = complete_df['file_name'][i]
    path ="./UrbanSound8K/audio/fold"+str(complete_df['fold'][i])+"/"+str(audio_name)

    x, sr = librosa.load(path)
     
    if p != 0:
        num = num + 1
    else: 
        num=1
              

    ax = fig.add_subplot(12,1,num)
    librosa.display.waveplot(x, sr=sr)
    ax.set_title("Class: {}".format(complete_df['class'][i]))
    
    num += 1
    ax = fig.add_subplot(12,1,num)
    librosa.display.specshow(np.array(complete_df['MELSPEC'][i]).T, sr = sr , hop_length = hop_length)
    ax.set_xlabel("Time")
    ax.set_title("MELSPECTROGRAM")
    
    num += 1
    ax = fig.add_subplot(12,1,num)
    librosa.display.specshow(np.array(complete_df['CHROMA'][i]).T)
    ax.set_xlabel("Time")
    ax.set_title("CHROMA")
    
fig.subplots_adjust(bottom=0.15, top=0.8)

# %% [markdown]
# We can start to notice some pattern (dis)similarity across and within classes in the time/frequency domain !
# Length of signal is quite different...

# %% [markdown]
# __Classes Distribution in the datasets__

# %%
complete_df["class"].value_counts()
# Out:
# engine_idling       1000
# air_conditioner     1000
# jackhammer          1000
# children_playing    1000
# street_music        1000
# drilling            1000
# dog_bark            1000
# siren                929
# car_horn             429
# gun_shot             374
# Name: class, dtype: int64

# %% [markdown]
# # Create the Convolutional Neural Network

# %% [markdown]
# ## Import packages

# %%
import numpy as np
import tensorflow as tf
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# %% [markdown]
# ## Build the Model

# %%
num_labels = 10
def build_model(input_shape, loss="sparse_categorical_crossentropy", learning_rate=0.001):

    # build network architecture using convolutional layers
    model = tf.keras.models.Sequential()

    # 1st conv layer
    model.add(tf.keras.layers.Conv2D(32, (3, 3), padding='same', input_shape=input_shape))
    model.add(tf.keras.layers.Activation('relu'))
    
    # 2nd conv layer
    model.add(tf.keras.layers.Conv2D(64, (3, 3)))
    model.add(tf.keras.layers.Activation('relu'))
    model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
    model.add(tf.keras.layers.Dropout(0.25))
    
    # 3rd conv layer
    model.add(tf.keras.layers.Conv2D(64, (3, 3)))
    model.add(tf.keras.layers.Activation('relu'))
    
    # 4th conv layer
    model.add(tf.keras.layers.Conv2D(64, (3, 3)))
    model.add(tf.keras.layers.Activation('relu'))
    model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
    model.add(tf.keras.layers.Dropout(0.5))
    
    # 5th conv layer
    model.add(tf.keras.layers.Conv2D(128, (3, 3)))
    model.add(tf.keras.layers.Activation('relu'))
    
    # 6th conv layer
    model.add(tf.keras.layers.Conv2D(128, (3, 3)))
    model.add(tf.keras.layers.Activation('relu'))
    model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
    model.add(tf.keras.layers.Dropout(0.5))
      
    # flatten output and feed into dense layer
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(256, activation='relu'))
    model.add(tf.keras.layers.Dropout(0.5))
    

    # softmax output layer
    model.add(tf.keras.layers.Dense(10, activation='softmax'))

    optimiser = tf.keras.optimizers.RMSprop(learning_rate=learning_rate)
    
    # compile model
    model.compile(optimizer=optimiser,
                  loss=loss,
                  metrics=["accuracy"])

    

    return model

# %% [markdown]
# # Train and Evaluate the model

# %% [markdown]
# ## Create Train and Validation Dataset

# %%
def prepare_dataset(test_reference_idx, validation = False, validation_size=0.3):
    
    i = test_reference_idx
    test_fold = [i]  #using two fold at a time for testing
    mask = complete_df['fold'].isin(test_fold)
    train_data = complete_df[~mask]
    test_data = complete_df[mask]
    
    
    X_train = np.stack([train_data['MELSPEC'].values.tolist(),train_data['CHROMA'].values.tolist()],axis=-1)
     
       
    X_test = np.stack([test_data['MELSPEC'].values.tolist(),test_data['CHROMA'].values.tolist()],axis=-1)
    
    
    y_train =  np.array(train_data['classID'])
    y_test =  np.array(test_data['classID'])
    
    if validation:
        X_train, X_validation, y_train, y_validation = train_test_split(X_train, 
                                                                        y_train, 
                                                                        test_size=validation_size)
    else:
        X_validation = X_test
        y_validation = y_test

    
    return X_train, y_train, X_validation, y_validation, X_test, y_test

# %% [markdown]
# ## Create Train function

# %%
def train(model, epochs, batch_size, patience, X_train, y_train, X_validation, y_validation):
    
    #callback to stop training if improvement too weak
    earlystop_callback = tf.keras.callbacks.EarlyStopping(monitor="accuracy", min_delta=0.001, patience=patience)

    # train model
    history = model.fit(X_train,
                        y_train,
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=(X_validation, y_validation),
                        callbacks=[earlystop_callback])
    return history

# %% [markdown]
# # Train and Evaluate the Model

# %% [markdown]
# ## Tensorflow configuration for GPU

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:# Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)

        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)

# %% [markdown]
# ## Plot Function

# %%
def plot_history(x, history):
    
    plt.figure(i)
    
    plt.plot(history.history['accuracy'], label='accuracy')
    plt.plot(history.history['val_accuracy'], label='val_accuracy')
    plt.ylabel("Accuracy")
    plt.xlabel("Epochs")
    plt.legend(loc="lower right")
    plt.title("Accuracy evaluation")
    plt.show()

# %% [markdown]
# ## Training, Validation and Testing using 10 fold

# %% [markdown]
# The given dataset was composed by 10 folder, at each iteration, one folder is used for testing and the other 9 for training.
#
# The training set might be further divided into training and validation sets with a validation size of 20%

# %%
#number of folds for cross validation
num_of_folds=3

#training hyperparameters
patience = 2
epochs = 40
batch_size = 64
learning_rate = 0.001

test_loss=[0]*num_of_folds
test_acc=[0]*num_of_folds
history=[0]*num_of_folds

for i in range(num_of_folds):
    
    
    model_path="./model" + str(i+1) + ".h5"
    
    p = i+1
    
    print("\nIteration : {}\nProcessing dataset with fold{} for testing\n".format(p,p))
    
    X_train, y_train, X_validation, y_validation, X_test, y_test = prepare_dataset(p,
                                                                                   validation=True,
                                                                                   validation_size=0.3)
    
    # create network
    
    input_shape = (X_train.shape[1], X_train.shape[2], 2)
    model = build_model(input_shape, learning_rate=learning_rate)
    # print model parameters on console
    model.summary()    
    # train network
    history[i] = train(model, epochs, batch_size, patience, X_train, y_train, X_validation, y_validation)
    
    
    # evaluate network on test set
    test_loss[i], test_acc[i] = model.evaluate(X_test, y_test)
    print("\nTest loss: {}, test accuracy: {}%".format(test_loss[i], 100*test_acc[i]))
    
    # plot accuracy/loss for training/validation set as a function of the epochs
    plot_history(i,history[i])
    
    #plot_history(i,history[i])  
    plt.show()

    # save model
    model.save(model_path)
# Out:
# Iteration : 1
# Processing dataset with fold1 for testing
#
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 173, 40, 32)       608
# _________________________________________________________________
# activation (Activation)      (None, 173, 40, 32)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 171, 38, 64)       18496
# _________________________________________________________________
# activation_1 (Activation)    (None, 171, 38, 64)       0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 85, 19, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 85, 19, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 83, 17, 64)        36928
# _________________________________________________________________
# activation_2 (Activation)    (None, 83, 17, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 81, 15, 64)        36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 81, 15, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 40, 7, 64)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 40, 7, 64)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 38, 5, 128)        73856
# _________________________________________________________________
# activation_4 (Activation)    (None, 38, 5, 128)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 36, 3, 128)        147584
# _________________________________________________________________
# activation_5 (Activation)    (None, 36, 3, 128)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 1, 128)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 18, 1, 128)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               590080
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 907,050
# Trainable params: 907,050
# Non-trainable params: 0
# _________________________________________________________________
# Train on 5501 samples, validate on 2358 samples
# Epoch 1/40
# 5501/5501 [==============================] - 217s 39ms/sample - loss: 2.2477 - accuracy: 0.1963 - val_loss: 2.0084 - val_accuracy: 0.2740
# Epoch 2/40
# 5501/5501 [==============================] - 212s 39ms/sample - loss: 1.9746 - accuracy: 0.2967 - val_loss: 1.7573 - val_accuracy: 0.3834
# Epoch 3/40
# 5501/5501 [==============================] - 213s 39ms/sample - loss: 1.7492 - accuracy: 0.3827 - val_loss: 1.6374 - val_accuracy: 0.4262
# Epoch 4/40
# 5501/5501 [==============================] - 212s 39ms/sample - loss: 1.5802 - accuracy: 0.4577 - val_loss: 1.4497 - val_accuracy: 0.5293
# Epoch 5/40
# 5501/5501 [==============================] - 212s 39ms/sample - loss: 1.4152 - accuracy: 0.5155 - val_loss: 1.1878 - val_accuracy: 0.5937
# Epoch 6/40
# 5501/5501 [==============================] - 212s 38ms/sample - loss: 1.2732 - accuracy: 0.5755 - val_loss: 1.3108 - val_accuracy: 0.5636
# Epoch 7/40
# 5501/5501 [==============================] - 213s 39ms/sample - loss: 1.1369 - accuracy: 0.6153 - val_loss: 1.1331 - val_accuracy: 0.6213
# Epoch 8/40
# 5501/5501 [==============================] - 212s 39ms/sample - loss: 1.0238 - accuracy: 0.6653 - val_loss: 1.0620 - val_accuracy: 0.6760
# Epoch 9/40
# 5501/5501 [==============================] - 212s 39ms/sample - loss: 0.9306 - accuracy: 0.6986 - val_loss: 0.8344 - val_accuracy: 0.7388
# Epoch 10/40
# 5501/5501 [==============================] - 212s 39ms/sample - loss: 0.8743 - accuracy: 0.7204 - val_loss: 0.8307 - val_accuracy: 0.7422
# Epoch 11/40
# 5501/5501 [==============================] - 212s 38ms/sample - loss: 0.7704 - accuracy: 0.7535 - val_loss: 0.7752 - val_accuracy: 0.7468
# Epoch 12/40
# 5501/5501 [==============================] - 212s 38ms/sample - loss: 0.7005 - accuracy: 0.7757 - val_loss: 0.7172 - val_accuracy: 0.7621
# Epoch 13/40
# 5501/5501 [==============================] - 212s 39ms/sample - loss: 0.6532 - accuracy: 0.7951 - val_loss: 0.7314 - val_accuracy: 0.7884
# Epoch 14/40
# 5501/5501 [==============================] - 212s 39ms/sample - loss: 0.6112 - accuracy: 0.8042 - val_loss: 0.8619 - val_accuracy: 0.7290
# Epoch 15/40
# 5501/5501 [==============================] - 213s 39ms/sample - loss: 0.5798 - accuracy: 0.8144 - val_loss: 0.6202 - val_accuracy: 0.8092
# Epoch 16/40
# 5501/5501 [==============================] - 214s 39ms/sample - loss: 0.5138 - accuracy: 0.8308 - val_loss: 0.6006 - val_accuracy: 0.8282
# Epoch 17/40
# 5501/5501 [==============================] - 212s 39ms/sample - loss: 0.4878 - accuracy: 0.8426 - val_loss: 0.7747 - val_accuracy: 0.8003
# Epoch 18/40
# 5501/5501 [==============================] - 212s 38ms/sample - loss: 0.4566 - accuracy: 0.8508 - val_loss: 0.5794 - val_accuracy: 0.8287
# Epoch 19/40
# 5501/5501 [==============================] - 212s 39ms/sample - loss: 0.4236 - accuracy: 0.8613 - val_loss: 0.5136 - val_accuracy: 0.8465
# Epoch 20/40
# 5501/5501 [==============================] - 212s 38ms/sample - loss: 0.4163 - accuracy: 0.8684 - val_loss: 0.5885 - val_accuracy: 0.8516
# Epoch 21/40
# 5501/5501 [==============================] - 212s 39ms/sample - loss: 0.4206 - accuracy: 0.8766 - val_loss: 0.5713 - val_accuracy: 0.8363
# Epoch 22/40
# 5501/5501 [==============================] - 212s 39ms/sample - loss: 0.3785 - accuracy: 0.8826 - val_loss: 0.5935 - val_accuracy: 0.8367
# Epoch 23/40
# 5501/5501 [==============================] - 212s 39ms/sample - loss: 0.3688 - accuracy: 0.8915 - val_loss: 0.6497 - val_accuracy: 0.8346
# Epoch 24/40
# 5501/5501 [==============================] - 212s 39ms/sample - loss: 0.3392 - accuracy: 0.8933 - val_loss: 0.6046 - val_accuracy: 0.8503
# Epoch 25/40
# 5501/5501 [==============================] - 212s 39ms/sample - loss: 0.3368 - accuracy: 0.9018 - val_loss: 0.6160 - val_accuracy: 0.8435
# Epoch 26/40
# 5501/5501 [==============================] - 211s 38ms/sample - loss: 0.3542 - accuracy: 0.8955 - val_loss: 0.6091 - val_accuracy: 0.8405
# Epoch 27/40
# 5501/5501 [==============================] - 212s 38ms/sample - loss: 0.3435 - accuracy: 0.9009 - val_loss: 0.9801 - val_accuracy: 0.8092
# 873/873 [==============================] - 7s 9ms/sample - loss: 3.4551 - accuracy: 0.5830
#
# Test loss: 3.4550571708096127, test accuracy: 58.30469727516174%
# Iteration : 2
# Processing dataset with fold2 for testing
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 173, 40, 32)       608
# _________________________________________________________________
# activation_6 (Activation)    (None, 173, 40, 32)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 171, 38, 64)       18496
# _________________________________________________________________
# activation_7 (Activation)    (None, 171, 38, 64)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 85, 19, 64)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 85, 19, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 83, 17, 64)        36928
# _________________________________________________________________
# activation_8 (Activation)    (None, 83, 17, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 81, 15, 64)        36928
# _________________________________________________________________
# activation_9 (Activation)    (None, 81, 15, 64)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 40, 7, 64)         0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 40, 7, 64)         0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 38, 5, 128)        73856
# _________________________________________________________________
# activation_10 (Activation)   (None, 38, 5, 128)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 36, 3, 128)        147584
# _________________________________________________________________
# activation_11 (Activation)   (None, 36, 3, 128)        0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 18, 1, 128)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 18, 1, 128)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               590080
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 907,050
# Trainable params: 907,050
# Non-trainable params: 0
# _________________________________________________________________
# Train on 5490 samples, validate on 2354 samples
# Epoch 1/40
# 5490/5490 [==============================] - 216s 39ms/sample - loss: 2.2889 - accuracy: 0.1867 - val_loss: 2.1234 - val_accuracy: 0.2018
# Epoch 2/40
# 5490/5490 [==============================] - 210s 38ms/sample - loss: 1.9668 - accuracy: 0.3138 - val_loss: 1.7372 - val_accuracy: 0.3849
# Epoch 3/40
# 5490/5490 [==============================] - 210s 38ms/sample - loss: 1.7383 - accuracy: 0.3951 - val_loss: 1.5466 - val_accuracy: 0.4486
# Epoch 4/40
# 5490/5490 [==============================] - 211s 38ms/sample - loss: 1.4933 - accuracy: 0.4823 - val_loss: 1.3646 - val_accuracy: 0.5251
# Epoch 5/40
# 5490/5490 [==============================] - 216s 39ms/sample - loss: 1.3458 - accuracy: 0.5428 - val_loss: 1.2982 - val_accuracy: 0.5701
# Epoch 6/40
# 5490/5490 [==============================] - 212s 39ms/sample - loss: 1.1305 - accuracy: 0.6209 - val_loss: 1.2106 - val_accuracy: 0.5986
# Epoch 7/40
# 5490/5490 [==============================] - 211s 38ms/sample - loss: 1.0107 - accuracy: 0.6707 - val_loss: 1.3396 - val_accuracy: 0.5943
# Epoch 8/40
# 5490/5490 [==============================] - 211s 38ms/sample - loss: 0.9200 - accuracy: 0.7015 - val_loss: 0.8385 - val_accuracy: 0.7239
# Epoch 9/40
# 5490/5490 [==============================] - 211s 38ms/sample - loss: 0.8215 - accuracy: 0.7275 - val_loss: 0.7903 - val_accuracy: 0.7562
# Epoch 10/40
# 5490/5490 [==============================] - 211s 38ms/sample - loss: 0.7583 - accuracy: 0.7470 - val_loss: 0.7383 - val_accuracy: 0.7710
# Epoch 11/40
# 5490/5490 [==============================] - 211s 38ms/sample - loss: 0.7178 - accuracy: 0.7696 - val_loss: 0.6701 - val_accuracy: 0.7872
# Epoch 12/40
# 5490/5490 [==============================] - 211s 38ms/sample - loss: 0.6542 - accuracy: 0.7845 - val_loss: 0.6375 - val_accuracy: 0.8122
# Epoch 13/40
# 5490/5490 [==============================] - 211s 39ms/sample - loss: 0.6164 - accuracy: 0.8033 - val_loss: 0.6274 - val_accuracy: 0.8127
# Epoch 14/40
# 5490/5490 [==============================] - 211s 38ms/sample - loss: 0.5607 - accuracy: 0.8228 - val_loss: 0.7228 - val_accuracy: 0.8033
# Epoch 15/40
# 5490/5490 [==============================] - 211s 38ms/sample - loss: 0.5429 - accuracy: 0.8237 - val_loss: 0.5870 - val_accuracy: 0.8343
# Epoch 16/40
# 5490/5490 [==============================] - 211s 38ms/sample - loss: 0.5090 - accuracy: 0.8337 - val_loss: 0.6748 - val_accuracy: 0.8267
# Epoch 17/40
# 5490/5490 [==============================] - 211s 38ms/sample - loss: 0.4563 - accuracy: 0.8536 - val_loss: 0.5990 - val_accuracy: 0.8377
# Epoch 18/40
# 5490/5490 [==============================] - 211s 38ms/sample - loss: 0.4389 - accuracy: 0.8574 - val_loss: 0.8739 - val_accuracy: 0.7995
# Epoch 19/40
# 5490/5490 [==============================] - 210s 38ms/sample - loss: 0.4638 - accuracy: 0.8596 - val_loss: 0.5900 - val_accuracy: 0.8415
# Epoch 20/40
# 5490/5490 [==============================] - 210s 38ms/sample - loss: 0.4120 - accuracy: 0.8694 - val_loss: 0.6389 - val_accuracy: 0.8462
# Epoch 21/40
# 5490/5490 [==============================] - 213s 39ms/sample - loss: 0.3981 - accuracy: 0.8749 - val_loss: 0.7297 - val_accuracy: 0.8199
# Epoch 22/40
# 5490/5490 [==============================] - 221s 40ms/sample - loss: 0.4108 - accuracy: 0.8736 - val_loss: 0.6510 - val_accuracy: 0.8301
# Epoch 23/40
# 5490/5490 [==============================] - 213s 39ms/sample - loss: 0.4142 - accuracy: 0.8814 - val_loss: 0.5212 - val_accuracy: 0.8666
# Epoch 24/40
# 5490/5490 [==============================] - 213s 39ms/sample - loss: 0.3229 - accuracy: 0.8956 - val_loss: 0.6222 - val_accuracy: 0.8598
# Epoch 25/40
# 5490/5490 [==============================] - 211s 38ms/sample - loss: 0.3541 - accuracy: 0.8869 - val_loss: 0.6192 - val_accuracy: 0.8530
# Epoch 26/40
# 5490/5490 [==============================] - 211s 38ms/sample - loss: 0.3479 - accuracy: 0.8918 - val_loss: 0.6642 - val_accuracy: 0.8547
# 888/888 [==============================] - 8s 9ms/sample - loss: 2.4169 - accuracy: 0.6070
#
# Test loss: 2.416907823837555, test accuracy: 60.69819927215576%
# Iteration : 3
# Processing dataset with fold3 for testing
#
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 173, 40, 32)       608
# _________________________________________________________________
# activation_12 (Activation)   (None, 173, 40, 32)       0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 171, 38, 64)       18496
# _________________________________________________________________
# activation_13 (Activation)   (None, 171, 38, 64)       0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 85, 19, 64)        0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 85, 19, 64)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 83, 17, 64)        36928
# _________________________________________________________________
# activation_14 (Activation)   (None, 83, 17, 64)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 81, 15, 64)        36928
# _________________________________________________________________
# activation_15 (Activation)   (None, 81, 15, 64)        0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 40, 7, 64)         0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 40, 7, 64)         0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 38, 5, 128)        73856
# _________________________________________________________________
# activation_16 (Activation)   (None, 38, 5, 128)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 36, 3, 128)        147584
# _________________________________________________________________
# activation_17 (Activation)   (None, 36, 3, 128)        0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 18, 1, 128)        0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 18, 1, 128)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               590080
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 907,050
# Trainable params: 907,050
# Non-trainable params: 0
# _________________________________________________________________
# Train on 5464 samples, validate on 2343 samples
# Epoch 1/40
# 5464/5464 [==============================] - 212s 39ms/sample - loss: 2.2514 - accuracy: 0.1867 - val_loss: 2.1250 - val_accuracy: 0.2373
# Epoch 2/40
# 5464/5464 [==============================] - 209s 38ms/sample - loss: 1.9766 - accuracy: 0.3056 - val_loss: 1.8214 - val_accuracy: 0.3645
# Epoch 3/40
# 5464/5464 [==============================] - 209s 38ms/sample - loss: 1.7353 - accuracy: 0.3924 - val_loss: 1.6825 - val_accuracy: 0.4191
# Epoch 4/40
# 5464/5464 [==============================] - 209s 38ms/sample - loss: 1.5257 - accuracy: 0.4674 - val_loss: 1.4359 - val_accuracy: 0.4942
# Epoch 5/40
# 5464/5464 [==============================] - 209s 38ms/sample - loss: 1.3644 - accuracy: 0.5284 - val_loss: 1.2691 - val_accuracy: 0.5992
# Epoch 6/40
# 5464/5464 [==============================] - 210s 38ms/sample - loss: 1.2205 - accuracy: 0.5957 - val_loss: 1.3191 - val_accuracy: 0.5455
# Epoch 7/40
# 5464/5464 [==============================] - 209s 38ms/sample - loss: 1.0919 - accuracy: 0.6363 - val_loss: 1.2477 - val_accuracy: 0.6449
# Epoch 8/40
# 5464/5464 [==============================] - 210s 38ms/sample - loss: 0.9953 - accuracy: 0.6673 - val_loss: 1.2408 - val_accuracy: 0.6394
# Epoch 9/40
# 5464/5464 [==============================] - 209s 38ms/sample - loss: 0.9127 - accuracy: 0.7072 - val_loss: 1.1381 - val_accuracy: 0.6837
# Epoch 10/40
# 5464/5464 [==============================] - 209s 38ms/sample - loss: 0.8445 - accuracy: 0.7310 - val_loss: 0.7578 - val_accuracy: 0.7700
# Epoch 11/40
# 5464/5464 [==============================] - 210s 38ms/sample - loss: 0.7678 - accuracy: 0.7553 - val_loss: 1.0445 - val_accuracy: 0.6726
# Epoch 12/40
# 5464/5464 [==============================] - 209s 38ms/sample - loss: 0.7110 - accuracy: 0.7736 - val_loss: 1.0246 - val_accuracy: 0.6812
# Epoch 13/40
# 5464/5464 [==============================] - 212s 39ms/sample - loss: 0.6552 - accuracy: 0.7912 - val_loss: 1.1096 - val_accuracy: 0.6816
# Epoch 14/40
# 5464/5464 [==============================] - 210s 38ms/sample - loss: 0.6451 - accuracy: 0.7989 - val_loss: 0.7095 - val_accuracy: 0.8032
# Epoch 15/40
# 5464/5464 [==============================] - 209s 38ms/sample - loss: 0.6027 - accuracy: 0.8122 - val_loss: 0.8145 - val_accuracy: 0.8186
# Epoch 16/40
# 5464/5464 [==============================] - 210s 38ms/sample - loss: 0.5642 - accuracy: 0.8241 - val_loss: 1.1461 - val_accuracy: 0.7358
# Epoch 17/40
# 5464/5464 [==============================] - 210s 38ms/sample - loss: 0.5286 - accuracy: 0.8316 - val_loss: 0.8249 - val_accuracy: 0.7900
# Epoch 18/40
# 5464/5464 [==============================] - 209s 38ms/sample - loss: 0.5083 - accuracy: 0.8400 - val_loss: 0.6926 - val_accuracy: 0.8233
# Epoch 19/40
# 5464/5464 [==============================] - 210s 38ms/sample - loss: 0.4807 - accuracy: 0.8519 - val_loss: 0.8777 - val_accuracy: 0.7738
# Epoch 20/40
# 5464/5464 [==============================] - 210s 38ms/sample - loss: 0.4561 - accuracy: 0.8501 - val_loss: 0.6920 - val_accuracy: 0.8289
# Epoch 21/40
# 5464/5464 [==============================] - 209s 38ms/sample - loss: 0.4169 - accuracy: 0.8644 - val_loss: 0.9725 - val_accuracy: 0.7828
# Epoch 22/40
# 5464/5464 [==============================] - 210s 38ms/sample - loss: 0.4265 - accuracy: 0.8633 - val_loss: 0.7694 - val_accuracy: 0.7930
# Epoch 23/40
# 5464/5464 [==============================] - 210s 39ms/sample - loss: 0.3894 - accuracy: 0.8735 - val_loss: 0.7539 - val_accuracy: 0.8169
# Epoch 24/40
# 5464/5464 [==============================] - 210s 38ms/sample - loss: 0.3934 - accuracy: 0.8730 - val_loss: 0.6242 - val_accuracy: 0.8468
# Epoch 25/40
# 5464/5464 [==============================] - 210s 38ms/sample - loss: 0.3939 - accuracy: 0.8776 - val_loss: 0.8115 - val_accuracy: 0.8301
# Epoch 26/40
# 5464/5464 [==============================] - 210s 38ms/sample - loss: 0.3567 - accuracy: 0.8924 - val_loss: 0.6515 - val_accuracy: 0.8557
# Epoch 27/40
# 5464/5464 [==============================] - 210s 38ms/sample - loss: 0.3624 - accuracy: 0.8904 - val_loss: 1.6742 - val_accuracy: 0.7687
# Epoch 28/40
# 5464/5464 [==============================] - 210s 38ms/sample - loss: 0.3756 - accuracy: 0.8904 - val_loss: 0.7739 - val_accuracy: 0.8344
# 925/925 [==============================] - 8s 8ms/sample - loss: 2.1850 - accuracy: 0.5514
#
# Test loss: 2.18503587426366, test accuracy: 55.13513684272766%

# %%
print(f"After {num_of_folds} fold cross validation, average resulting test accuracy is: {100*np.mean(test_acc)} %")
# Out:
# After 3 fold cross validation, average resulting test accuracy is: 58.04600715637207 %
