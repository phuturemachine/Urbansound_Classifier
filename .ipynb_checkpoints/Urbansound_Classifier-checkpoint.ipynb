# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction-and-dataset-exploration" data-toc-modified-id="Introduction-and-dataset-exploration-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction and dataset exploration</a></span><ul class="toc-item"><li><span><a href="#Import-Packages" data-toc-modified-id="Import-Packages-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Import Packages</a></span></li><li><span><a href="#Explore-data" data-toc-modified-id="Explore-data-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Explore data</a></span></li><li><span><a href="#Prepare-working-dataset" data-toc-modified-id="Prepare-working-dataset-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Prepare working dataset</a></span></li></ul></li><li><span><a href="#Create-the-Convolutional-Neural-Network" data-toc-modified-id="Create-the-Convolutional-Neural-Network-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Create the Convolutional Neural Network</a></span><ul class="toc-item"><li><span><a href="#Import-packages" data-toc-modified-id="Import-packages-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Import packages</a></span></li><li><span><a href="#Build-the-Model" data-toc-modified-id="Build-the-Model-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Build the Model</a></span></li></ul></li><li><span><a href="#Train-and-Evaluate-the-model" data-toc-modified-id="Train-and-Evaluate-the-model-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Train and Evaluate the model</a></span><ul class="toc-item"><li><span><a href="#Create-Train-and-Validation-Dataset" data-toc-modified-id="Create-Train-and-Validation-Dataset-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Create Train and Validation Dataset</a></span></li><li><span><a href="#Create-Train-function" data-toc-modified-id="Create-Train-function-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Create Train function</a></span></li></ul></li><li><span><a href="#Train-and-Evaluate-the-Model" data-toc-modified-id="Train-and-Evaluate-the-Model-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Train and Evaluate the Model</a></span><ul class="toc-item"><li><span><a href="#Tensorflow-configuration-for-GPU" data-toc-modified-id="Tensorflow-configuration-for-GPU-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Tensorflow configuration for GPU</a></span></li><li><span><a href="#Plot-Function" data-toc-modified-id="Plot-Function-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Plot Function</a></span></li><li><span><a href="#Training,-Validation-and-Testing-using-10-fold" data-toc-modified-id="Training,-Validation-and-Testing-using-10-fold-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Training, Validation and Testing using 10 fold</a></span></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Conclusion</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Introduction and dataset exploration

# %% [markdown]
# __Urban Sound Audio Classification __
#
# https://urbansounddataset.weebly.com/urbansound8k.html
#
# __Dataset Description__
#
# This dataset contains 8732 labeled sound excerpts (<=4s) of urban sounds from 10 classes: air_conditioner, car_horn, children_playing, dog_bark, drilling, enginge_idling, gun_shot, jackhammer, siren, and street_music. The classes are drawn from the urban sound taxonomy. For a detailed description of the dataset and how it was compiled please refer to our paper.
# All excerpts are taken from field recordings uploaded to www.freesound.org. The files are pre-sorted into ten folds (folders named fold1-fold10) to help in the reproduction of and comparison with the automatic classification results reported in the article above.
#
# __Audio Files Included__
#
# 8732 audio files of urban sounds (see description above) in WAV format. The sampling rate, bit depth, and number of channels are the same as those of the original file uploaded to Freesound (and hence may vary from file to file).
#
# __Meta-data Files Included__
#
# UrbanSound8k.csv
#
# This file contains meta-data information about every audio file in the dataset. This includes:
#
# * slice_file_name:
# The name of the audio file. The name takes the following format: [fsID]-[classID]-[occurrenceID]-[sliceID].wav, where:
# [fsID] = the Freesound ID of the recording from which this excerpt (slice) is taken
# [classID] = a numeric identifier of the sound class (see description of classID below for further details)
# [occurrenceID] = a numeric identifier to distinguish different occurrences of the sound within the original recording
# [sliceID] = a numeric identifier to distinguish different slices taken from the same occurrence
#
# * fsID:
# The Freesound ID of the recording from which this excerpt (slice) is taken
#
# * start
# The start time of the slice in the original Freesound recording
#
# * end:
# The end time of slice in the original Freesound recording
#
# * salience:
# A (subjective) salience rating of the sound. 1 = foreground, 2 = background.
#
# * fold:
# The fold number (1-10) to which this file has been allocated.
#
# * classID:
#
# A numeric identifier of the sound class:
#
# 0 = air_conditioner
#
# 1 = car_horn
#
# 2 = children_playing
#
# 3 = dog_bark
#
# 4 = drilling
#
# 5 = engine_idling
#
# 6 = gun_shot
#
# 7 = jackhammer
#
# 8 = siren
#
# 9 = street_music
#
# * class:
# The class name: air_conditioner, car_horn, children_playing, dog_bark, drilling, engine_idling, gun_shot, jackhammer,
# siren, street_music.

# %% [markdown]
# ## Import Packages

# %%
import IPython
import IPython.display as ipd
import librosa
import librosa.display
import os
import os.path
import pandas as pd
import numpy as np
import glob 
import matplotlib.pyplot as plt
import json
import random

# %pylab inline
# %matplotlib inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/sambapunx/.conda/envs/TENSORFLOW/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['random']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# ## Explore data

# %% [markdown]
# Listen to one dataset sample example:

# %%
ipd.Audio('./UrbanSound8K/audio/fold1/7061-6-0-0.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Load and plot the audio file in the notebook using librosa. the output of librosa.load() is a numpy array with the audio data and the corrisponding sample rate

# %%
#load data
audiofile, sr = librosa.load('./UrbanSound8K/audio/fold1/7061-6-0-0.wav')

#plot
plt.figure(figsize=(12, 4))
librosa.display.waveplot(audiofile, sr=sr)

# %% [markdown]
# Plot 4 random samples from trainset to have a first figure of different classes waveform shapes, envelopes..

# %% [markdown]
# ## Prepare working dataset

# %% [markdown]
# Steps
#
# 1) Load metadata from the given .csv file into a pandas dataframe
#
# 2) Compute MFCCs/Chroma coefficient calculation for each sample
#
# 3) Create another pandas dataframe with the MFCCs/Chroma coefficients and the file name associated with
#
# 4) Merge the two pandas dataframes matching rows with same file name

# %%
# Step 1

data_dir ='./UrbanSound8K/audio/'

# load sample ids and labels from csv for test and train datasets
metadata_df = pd.read_csv('./UrbanSound8K/metadata/UrbanSound8K.csv')
del metadata_df['fsID']
del metadata_df['start']
del metadata_df['end']
del metadata_df['salience']

metadata_df
# Out:
#          slice_file_name  fold  classID             class
# 0       100032-3-0-0.wav     5        3          dog_bark
# 1     100263-2-0-117.wav     5        2  children_playing
# 2     100263-2-0-121.wav     5        2  children_playing
# 3     100263-2-0-126.wav     5        2  children_playing
# 4     100263-2-0-137.wav     5        2  children_playing
# ...                  ...   ...      ...               ...
# 8727     99812-1-2-0.wav     7        1          car_horn
# 8728     99812-1-3-0.wav     7        1          car_horn
# 8729     99812-1-4-0.wav     7        1          car_horn
# 8730     99812-1-5-0.wav     7        1          car_horn
# 8731     99812-1-6-0.wav     7        1          car_horn
#
# [8732 rows x 4 columns]

# %%
###### Step 2 & 3: Compute MFCCs coefficient
# Create pandas dataframe for ease of matching with metadata_df, save it also to json file

Tot_bins = 22050 * 1 #2 seconds long signals 

#chroma and MFCCs parameters
fmin= librosa.midi_to_hz(36)  
sr = 22050
n_mfcc=36
n_fft=2048
hop_length=512

features = {"MFCCs": [], "Chroma":[],"Tonnetz":[], "file_name": []}

dataset_path= './UrbanSound8K/audio/'
json_path = "./UrbanSound8K/metadata/extracted_features.json"

"""
since the mffc coefficient calculation might take a while, 
it is better to save results in a json file.
the following if/else statements simply check if this calculation has already been made,
and simply load last computed data from the relative json file
"""

if os.path.isfile(json_path):
    with open(json_path, "r") as fp:
        data = json.load(fp)
        features["MFCCs"] = data["MFCCs"]
        features["Chroma"] = data["Chroma"]
        features["Tonnetz"] = data["Tonnetz"]
        
        for i in range(len(data["file_name"])):
            data["file_name"][i] = data["file_name"][i].split("/")[-1]
        
        features["file_name"] = data["file_name"]
        
    features_df = pd.DataFrame(features)
    
else:
    # WARNING --> This might take a while, plenty of mfccs calculation 
    
    for (dirpath, dirnames, filenames) in os.walk(dataset_path):
        # ensure we're at sub-folder level
        if dirpath is not dataset_path:
        # process all audio files in sub-dir and store MFCCs
            for f in filenames:
                file_path = os.path.join(dirpath, f)
                if file_path.endswith('.wav'):
                    
                    # load audio file and slice it to ensure length consistency among different files
                    
                    signal, sample_rate = librosa.load(file_path)
                    signal2=np.array([float(0)]*Tot_bins)
                    # adjust signal length
                    if len(signal) >= Tot_bins:
                        # ensure consistency of the length of the signal
                        signal = signal[:Tot_bins]
                    elif len(signal) < Tot_bins:
                        signal2[:len(signal)]=signal
                        signal = signal2
                        
                    # extract MFCCs, Chroma
                    MFCCs = librosa.feature.mfcc(signal, sr = sr, n_mfcc= 36, n_fft= n_fft, hop_length=hop_length)
                    CHROMA = librosa.feature.chroma_cqt(signal, sr=sr, fmin=fmin, n_chroma = 36, hop_length = hop_length)
                    TONNETZ = librosa.feature.tonnetz(signal, sr=sr, chroma = CHROMA)
                    
                    
                    # store data for analysed track
                    features["MFCCs"].append(MFCCs.T.tolist())
                    features["Chroma"].append(CHROMA.T.tolist())
                    features["Tonnetz"].append(TONNETZ.T.tolist())
                    features["file_name"].append(file_path.split("/")[-1])

    features_df = pd.DataFrame(features)
    # save data in json file
    with open(json_path, "w") as fp:
        json.dump(features, fp, indent=4)
    
    
#adjust tonnetz depth 6 -> 36 as MFCCs and Chroma
if features_df['Tonnetz'][0][0] != features_df['Chroma'][0][0]:
    for u in range(len(features_df['Tonnetz'])):
    
        for v in range(len(features_df['Tonnetz'][u])):
            a=[]
            for n in range(len(features_df['Tonnetz'][u][v])):
                a += [features_df['Tonnetz'][u][v][n]]*int(n_mfcc/6)
        
            features_df['Tonnetz'][u][v]=a
            
print(f'The number of keys for the features dictionary is: {len(features)}')
print(f'For each key the corresponding number of samples is: {len(features_df["MFCCs"])}')
print(f'For each .wav sample the number of hop/time windows considered for MFFCs and CHROMA are: {len(features_df["MFCCs"][0])}')
print(f'For each time window in a sample, the number of MFCC coeffiecients (and CHROMA depth) is: {len(features_df["Tonnetz"][0][0])}')
       

features_df

# %%
# Step 4: Merge DataFrames
metadata_df.rename(columns={'slice_file_name': 'file_name'}, inplace=True)
complete_df = pd.merge(metadata_df, features_df, on='file_name',how='inner')

#free some memory
del features
del features_df
del metadata_df

complete_df
# Out:
#         file_name  fold  classID          class  \
# 0   344-3-0-0.wav     4        3       dog_bark
# 1   344-3-1-0.wav     4        3       dog_bark
# 2  4201-3-0-0.wav     2        3       dog_bark
# 3  4910-3-0-0.wav     6        3       dog_bark
# 4  4912-3-0-0.wav     6        3       dog_bark
# 5  6508-9-0-1.wav     5        9   street_music
# 6  6508-9-0-2.wav     5        9   street_music
# 7  6988-5-0-0.wav     3        5  engine_idling
# 8  6988-5-0-1.wav     3        5  engine_idling
# 9  7061-6-0-0.wav     1        6       gun_shot
#
#                                                MFCCs  \
# 0  [[-265.1651306152344, 137.99856567382812, 11.9...
# 1  [[-293.6439514160156, 125.50192260742188, 22.4...
# 2  [[-527.5209350585938, 131.53311157226562, 19.8...
# 3  [[-171.74777221679688, 161.5313720703125, -48....
# 4  [[-215.9828338623047, 200.38511657714844, -10....
# 5  [[-217.55441284179688, 155.1742706298828, 11.2...
# 6  [[-195.25955200195312, 169.6287841796875, -15....
# 7  [[-232.4698486328125, 125.65342712402344, -0.0...
# 8  [[-152.92210388183594, 164.3134307861328, -11....
# 9  [[-93.80020141601562, 30.77403450012207, -3.28...
#
#                                               Chroma  \
# 0  [[0.34838227531517996, 0.6497133856855376, 0.5...
# 1  [[0.26936134689297647, 0.3904823414872573, 0.3...
# 2  [[0.2553826273083242, 0.11639785138442366, 0.8...
# 3  [[0.5444572439816703, 0.9615111721183452, 0.76...
# 4  [[0.6585683779317169, 0.8456631413035274, 0.49...
# 5  [[1.0, 0.5374531207776728, 0.3582729999660573,...
# 6  [[0.302924043897969, 0.3434286465968799, 0.334...
# 7  [[0.6883321302916077, 0.8570202432662241, 0.28...
# 8  [[0.18667844600042502, 0.6960806637917636, 1.0...
# 9  [[0.731579443734636, 0.828151977274392, 0.8243...
#
#                                              Tonnetz
# 0  [[-0.062039093031448674, -0.062039093031448674...
# 1  [[-0.06200404368414845, -0.06200404368414845, ...
# 2  [[0.044800231578813667, 0.044800231578813667, ...
# 3  [[0.0161458277739174, 0.0161458277739174, 0.01...
# 4  [[0.05080071768324287, 0.05080071768324287, 0....
# 5  [[0.009295620935311536, 0.009295620935311536, ...
# 6  [[-0.009805343279885581, -0.009805343279885581...
# 7  [[0.09166991861382436, 0.09166991861382436, 0....
# 8  [[0.0072963049434882216, 0.0072963049434882216...
# 9  [[-0.02448603184417496, -0.02448603184417496, ...

# %% [markdown]
# __further data exploration__
#
# Plot 4 random waveforms and corresponding mel-spectrum from the dataset indicating class

# %%
## initialize figure for plotting
fig = plt.figure(figsize=(18, 40))

#select 4 random index from train dataset available indexes           
for p in range(4):
    
    
    i=p#random.randint(0, 8731)
    
    audio_name = complete_df['file_name'][i]
    path ="./UrbanSound8K/audio/fold"+str(complete_df['fold'][i])+"/"+str(audio_name)

    x, sr = librosa.load(path)
     
    if p != 0:
        num = num + 1
    else: 
        num=1
              

    ax = fig.add_subplot(12,1,num)
    librosa.display.waveplot(x, sr=sr)
    ax.set_title("Class: {}".format(complete_df['class'][i]))
    
    num += 1
    ax = fig.add_subplot(12,1,num)
    librosa.display.specshow(np.array(complete_df['MFCCs'][i]).T, sr = sr , hop_length = hop_length)
    ax.set_xlabel("Time")
    ax.set_ylabel("MFCC")
    
    num += 1
    ax = fig.add_subplot(12,1,num)
    librosa.display.specshow(np.array(complete_df['Chroma'][i]).T)
    ax.set_xlabel("Time")
    ax.set_ylabel("Chroma")
    
fig.subplots_adjust(bottom=0.15, top=0.8)

# %% [markdown]
# We can start to notice some pattern (dis)similarity across and within classes in the time/frequency domain !
# Length of signal is quite different...

# %% [markdown]
# __Classes Distribution in the datasets__

# %%
complete_df["class"].value_counts()
# Out:
# dog_bark         5
# engine_idling    2
# street_music     2
# gun_shot         1
# Name: class, dtype: int64

# %% [markdown]
# Dataset is balanced for most of the classes except for "car_horn" and "gun_shot" classes

# %% [markdown]
# # Create the Convolutional Neural Network

# %% [markdown]
# ## Import packages

# %%
import numpy as np
import tensorflow as tf
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Build the Model

# %%
num_labels = 10
def build_model(input_shape, loss="sparse_categorical_crossentropy", learning_rate=0.0001):

    # build network architecture using convolutional layers
    model = tf.keras.models.Sequential()

    # 1st conv layer
    model.add(tf.keras.layers.Conv2D(128, (3, 3), activation='relu', input_shape=input_shape,
                                     kernel_regularizer=tf.keras.regularizers.l2(0.001)))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.MaxPooling2D((3, 3), strides=(2,2), padding='same'))
    tf.keras.layers.Dropout(0.2)

    # 2nd conv layer
    model.add(tf.keras.layers.Conv2D(128, (3, 3), activation='relu',
                                     kernel_regularizer=tf.keras.regularizers.l2(0.001)))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.MaxPooling2D((3, 3), strides=(2,2), padding='same'))
    tf.keras.layers.Dropout(0.2)

    """# 3rd conv layer
    model.add(tf.keras.layers.Conv2D(64, (2, 2), activation='relu',
                                     kernel_regularizer=tf.keras.regularizers.l2(0.001)))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.MaxPooling2D((2, 2), strides=(2,2), padding='same'))
    tf.keras.layers.Dropout(0.2)"""

    # flatten output and feed into dense layer
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(64, activation='relu'))
    tf.keras.layers.Dropout(0.1)

    # softmax output layer
    model.add(tf.keras.layers.Dense(10, activation='softmax'))

    optimiser = tf.keras.optimizers.Adam(learning_rate=learning_rate)

    # compile model
    model.compile(optimizer=optimiser,
                  loss=loss,
                  metrics=["accuracy"])

    # print model parameters on console
    model.summary()

    return model

# %% [markdown]
# # Train and Evaluate the model

# %% [markdown]
# ## Create Train and Validation Dataset

# %%
def prepare_dataset(test_reference_idx, validation = False, validation_size=0.3):
    
    i = test_reference_idx
    test_fold = [i]  #using two fold at a time for testing
    mask = complete_df['fold'].isin(test_fold)
    train_data = complete_df[~mask]
    test_data = complete_df[mask]
    

    X_train = np.stack((np.rollaxis(np.dstack(train_data['MFCCs'].to_list()),-1),
                       np.rollaxis(np.dstack(train_data['Chroma'].to_list()),-1),
                       np.rollaxis(np.dstack(train_data['Tonnetz'].to_list()),-1)),
                      axis=-1)
   
    X_test = np.stack((np.rollaxis(np.dstack(test_data['MFCCs'].to_list()),-1),
                       np.rollaxis(np.dstack(test_data['Chroma'].to_list()),-1),
                       np.rollaxis(np.dstack(test_data['Tonnetz'].to_list()),-1)),
                      axis=-1)
   
    
    y_train =  np.array(train_data['classID'])
    y_test =  np.array(test_data['classID'])
    
    if validation:
        X_train, X_validation, y_train, y_validation = train_test_split(X_train, 
                                                                        y_train, 
                                                                        test_size=validation_size)
    else:
        X_validation = X_test
        y_validation = y_test

    
    return X_train, y_train, X_validation, y_validation, X_test, y_test

# %% [markdown]
# ## Create Train function

# %%
def train(model, epochs, batch_size, patience, X_train, y_train, X_validation, y_validation):
    
    #callback to stop training if improvement too low
    earlystop_callback = tf.keras.callbacks.EarlyStopping(monitor="accuracy", min_delta=0.001, patience=patience)

    # train model
    history = model.fit(X_train,
                        y_train,
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=(X_validation, y_validation),
                        callbacks=[earlystop_callback])
    return history

# %% [markdown]
# # Train and Evaluate the Model

# %% [markdown]
# ## Tensorflow configuration for GPU

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:# Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)

        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)

# %% [markdown]
# ## Plot Function

# %%
def plot_history(x, history):
    
    plt.figure(i)
    
    plt.plot(history.history['accuracy'], label='accuracy')
    plt.plot(history.history['val_accuracy'], label='val_accuracy')
    plt.ylabel("Accuracy")
    plt.xlabel("Epochs")
    plt.legend(loc="lower right")
    plt.title("Accuracy evaluation")
    plt.show()

# %% [markdown]
# ## Training, Validation and Testing using 10 fold

# %% [markdown]
# The given dataset was composed by 10 folder, at each iteration, one folder is used for testing and the other 9 for training.
#
# The training set is further divided into training and validation sets with a validation size of 20%

# %%
#number of folds for cross validation
#num_of_folds=10
num_of_folds=10

#training hyperparameters
patience = 3
epochs = 30
batch_size = 64
learning_rate = 0.0001

test_loss=[0]*num_of_folds
test_acc=[0]*num_of_folds
history=[0]*num_of_folds

for i in range(num_of_folds):
    
    
    model_path="./Bmodel" + str(i+1) + ".h5"
    
    p = i+1
    
    print("\nIteration : {}\nProcessing dataset with fold{} for testing\n".format(p,p))
    
    X_train, y_train, X_validation, y_validation, X_test, y_test = prepare_dataset(p,
                                                                                   validation=True,
                                                                                   validation_size=0.3)
    

    # create network
    
    input_shape = (X_train.shape[1], X_train.shape[2], 3)
    model = build_model(input_shape, learning_rate=learning_rate)
        
    # train network
    history[i] = train(model, epochs, batch_size, patience, X_train, y_train, X_validation, y_validation)

    # evaluate network on test set
    test_loss[i], test_acc[i] = model.evaluate(X_test, y_test)
    print("\nTest loss: {}, test accuracy: {}%".format(test_loss[i], 100*test_acc[i]))
    
    # plot accuracy/loss for training/validation set as a function of the epochs
    plot_history(i,history[i]) #plt.subplots(num_of_folds)
    
    #plot_history(i,history[i])  
    plt.show()

    # save model
    model.save(model_path)
# Out:
# Iteration : 1
# Processing dataset with fold1 for testing
#
# Model: "sequential_33"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_65 (Conv2D)           (None, 42, 34, 128)       3584
# _________________________________________________________________
# batch_normalization_63 (Batc (None, 42, 34, 128)       512
# _________________________________________________________________
# max_pooling2d_63 (MaxPooling (None, 21, 17, 128)       0
# _________________________________________________________________
# conv2d_66 (Conv2D)           (None, 19, 15, 128)       147584
# _________________________________________________________________
# batch_normalization_64 (Batc (None, 19, 15, 128)       512
# _________________________________________________________________
# max_pooling2d_64 (MaxPooling (None, 10, 8, 128)        0
# _________________________________________________________________
# flatten_31 (Flatten)         (None, 10240)             0
# _________________________________________________________________
# dense_62 (Dense)             (None, 64)                655424
# _________________________________________________________________
# dense_63 (Dense)             (None, 10)                650
# =================================================================
# Total params: 808,266
# Trainable params: 807,754
# Non-trainable params: 512
# _________________________________________________________________
# Train on 9 samples, validate on 1 samples
# Epoch 1/30
# 9/9 [==============================] - 2s 231ms/sample - loss: 5.4907 - accuracy: 0.1111 - val_loss: 2.9026 - val_accuracy: 0.0000e+00
# Epoch 2/30
# 9/9 [==============================] - 0s 13ms/sample - loss: 2.1991 - accuracy: 0.3333 - val_loss: 3.1973 - val_accuracy: 0.0000e+00
# Epoch 3/30
# 9/9 [==============================] - 0s 13ms/sample - loss: 0.5408 - accuracy: 1.0000 - val_loss: 3.5964 - val_accuracy: 0.0000e+00
# Epoch 4/30
# 9/9 [==============================] - 0s 14ms/sample - loss: 0.2199 - accuracy: 1.0000 - val_loss: 4.1288 - val_accuracy: 0.0000e+00
# Epoch 5/30
# 9/9 [==============================] - 0s 14ms/sample - loss: 0.1796 - accuracy: 1.0000 - val_loss: 4.5562 - val_accuracy: 0.0000e+00
# Epoch 6/30
# 9/9 [==============================] - 0s 14ms/sample - loss: 0.1642 - accuracy: 1.0000 - val_loss: 4.9614 - val_accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 10ms/sample - loss: 4.9614 - accuracy: 0.0000e+00
#
# Test loss: 4.961432933807373, test accuracy: 0.0%
# Iteration : 2
# Processing dataset with fold2 for testing
#
# Model: "sequential_34"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_67 (Conv2D)           (None, 42, 34, 128)       3584
# _________________________________________________________________
# batch_normalization_65 (Batc (None, 42, 34, 128)       512
# _________________________________________________________________
# max_pooling2d_65 (MaxPooling (None, 21, 17, 128)       0
# _________________________________________________________________
# conv2d_68 (Conv2D)           (None, 19, 15, 128)       147584
# _________________________________________________________________
# batch_normalization_66 (Batc (None, 19, 15, 128)       512
# _________________________________________________________________
# max_pooling2d_66 (MaxPooling (None, 10, 8, 128)        0
# _________________________________________________________________
# flatten_32 (Flatten)         (None, 10240)             0
# _________________________________________________________________
# dense_64 (Dense)             (None, 64)                655424
# _________________________________________________________________
# dense_65 (Dense)             (None, 10)                650
# =================================================================
# Total params: 808,266
# Trainable params: 807,754
# Non-trainable params: 512
# _________________________________________________________________
# Train on 9 samples, validate on 1 samples
# Epoch 1/30
# 9/9 [==============================] - 2s 214ms/sample - loss: 3.3573 - accuracy: 0.0000e+00 - val_loss: 2.3021 - val_accuracy: 0.0000e+00
# Epoch 2/30
# 9/9 [==============================] - 0s 14ms/sample - loss: 0.8496 - accuracy: 1.0000 - val_loss: 0.7891 - val_accuracy: 1.0000
# Epoch 3/30
# 9/9 [==============================] - 0s 15ms/sample - loss: 0.2849 - accuracy: 1.0000 - val_loss: 0.4060 - val_accuracy: 1.0000
# Epoch 4/30
# 9/9 [==============================] - 0s 15ms/sample - loss: 0.1816 - accuracy: 1.0000 - val_loss: 0.2569 - val_accuracy: 1.0000
# Epoch 5/30
# 9/9 [==============================] - 0s 13ms/sample - loss: 0.1533 - accuracy: 1.0000 - val_loss: 0.1894 - val_accuracy: 1.0000
# 1/1 [==============================] - 0s 10ms/sample - loss: 0.1894 - accuracy: 1.0000
#
# Test loss: 0.18944460153579712, test accuracy: 100.0%
# Iteration : 3
# Processing dataset with fold3 for testing
#
# Model: "sequential_35"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_69 (Conv2D)           (None, 42, 34, 128)       3584
# _________________________________________________________________
# batch_normalization_67 (Batc (None, 42, 34, 128)       512
# _________________________________________________________________
# max_pooling2d_67 (MaxPooling (None, 21, 17, 128)       0
# _________________________________________________________________
# conv2d_70 (Conv2D)           (None, 19, 15, 128)       147584
# _________________________________________________________________
# batch_normalization_68 (Batc (None, 19, 15, 128)       512
# _________________________________________________________________
# max_pooling2d_68 (MaxPooling (None, 10, 8, 128)        0
# _________________________________________________________________
# flatten_33 (Flatten)         (None, 10240)             0
# _________________________________________________________________
# dense_66 (Dense)             (None, 64)                655424
# _________________________________________________________________
# dense_67 (Dense)             (None, 10)                650
# =================================================================
# Total params: 808,266
# Trainable params: 807,754
# Non-trainable params: 512
# _________________________________________________________________
# Train on 8 samples, validate on 2 samples
# Epoch 1/30
# 8/8 [==============================] - 2s 239ms/sample - loss: 3.5607 - accuracy: 0.0000e+00 - val_loss: 3.3622 - val_accuracy: 0.0000e+00
# Epoch 2/30
# 8/8 [==============================] - 0s 13ms/sample - loss: 0.6716 - accuracy: 0.8750 - val_loss: 4.8042 - val_accuracy: 0.0000e+00
# Epoch 3/30
# 8/8 [==============================] - 0s 13ms/sample - loss: 0.2188 - accuracy: 1.0000 - val_loss: 6.0734 - val_accuracy: 0.0000e+00
# Epoch 4/30
# 8/8 [==============================] - 0s 13ms/sample - loss: 0.1523 - accuracy: 1.0000 - val_loss: 7.0840 - val_accuracy: 0.0000e+00
# Epoch 5/30
# 8/8 [==============================] - 0s 14ms/sample - loss: 0.1394 - accuracy: 1.0000 - val_loss: 7.9156 - val_accuracy: 0.0000e+00
# Epoch 6/30
# 8/8 [==============================] - 0s 15ms/sample - loss: 0.1361 - accuracy: 1.0000 - val_loss: 8.6087 - val_accuracy: 0.0000e+00
# 2/2 [==============================] - 0s 6ms/sample - loss: 8.6087 - accuracy: 0.0000e+00
#
# Test loss: 8.608664512634277, test accuracy: 0.0%
# Iteration : 4
# Processing dataset with fold4 for testing
#
# Model: "sequential_36"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_71 (Conv2D)           (None, 42, 34, 128)       3584
# _________________________________________________________________
# batch_normalization_69 (Batc (None, 42, 34, 128)       512
# _________________________________________________________________
# max_pooling2d_69 (MaxPooling (None, 21, 17, 128)       0
# _________________________________________________________________
# conv2d_72 (Conv2D)           (None, 19, 15, 128)       147584
# _________________________________________________________________
# batch_normalization_70 (Batc (None, 19, 15, 128)       512
# _________________________________________________________________
# max_pooling2d_70 (MaxPooling (None, 10, 8, 128)        0
# _________________________________________________________________
# flatten_34 (Flatten)         (None, 10240)             0
# _________________________________________________________________
# dense_68 (Dense)             (None, 64)                655424
# _________________________________________________________________
# dense_69 (Dense)             (None, 10)                650
# =================================================================
# Total params: 808,266
# Trainable params: 807,754
# Non-trainable params: 512
# _________________________________________________________________
# Train on 8 samples, validate on 2 samples
# Epoch 1/30
# 8/8 [==============================] - 2s 238ms/sample - loss: 3.1412 - accuracy: 0.3750 - val_loss: 0.6812 - val_accuracy: 1.0000
# Epoch 2/30
# 8/8 [==============================] - 0s 13ms/sample - loss: 0.6453 - accuracy: 0.8750 - val_loss: 0.6924 - val_accuracy: 0.5000
# Epoch 3/30
# 8/8 [==============================] - 0s 14ms/sample - loss: 0.2398 - accuracy: 1.0000 - val_loss: 0.9826 - val_accuracy: 0.5000
# Epoch 4/30
# 8/8 [==============================] - 0s 13ms/sample - loss: 0.1684 - accuracy: 1.0000 - val_loss: 1.4837 - val_accuracy: 0.5000
# Epoch 5/30
# 8/8 [==============================] - 0s 13ms/sample - loss: 0.1480 - accuracy: 1.0000 - val_loss: 1.9838 - val_accuracy: 0.5000
# Epoch 6/30
# 8/8 [==============================] - 0s 13ms/sample - loss: 0.1405 - accuracy: 1.0000 - val_loss: 2.4300 - val_accuracy: 0.5000
# 2/2 [==============================] - 0s 6ms/sample - loss: 2.4300 - accuracy: 0.5000
#
# Test loss: 2.429997205734253, test accuracy: 50.0%
# Iteration : 5
# Processing dataset with fold5 for testing
#
# Model: "sequential_37"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_73 (Conv2D)           (None, 42, 34, 128)       3584
# _________________________________________________________________
# batch_normalization_71 (Batc (None, 42, 34, 128)       512
# _________________________________________________________________
# max_pooling2d_71 (MaxPooling (None, 21, 17, 128)       0
# _________________________________________________________________
# conv2d_74 (Conv2D)           (None, 19, 15, 128)       147584
# _________________________________________________________________
# batch_normalization_72 (Batc (None, 19, 15, 128)       512
# _________________________________________________________________
# max_pooling2d_72 (MaxPooling (None, 10, 8, 128)        0
# _________________________________________________________________
# flatten_35 (Flatten)         (None, 10240)             0
# _________________________________________________________________
# dense_70 (Dense)             (None, 64)                655424
# _________________________________________________________________
# dense_71 (Dense)             (None, 10)                650
# =================================================================
# Total params: 808,266
# Trainable params: 807,754
# Non-trainable params: 512
# _________________________________________________________________
# Train on 8 samples, validate on 2 samples
# Epoch 1/30
# 8/8 [==============================] - 2s 238ms/sample - loss: 2.0938 - accuracy: 0.2500 - val_loss: 1.7731 - val_accuracy: 0.0000e+00
# Epoch 2/30
# 8/8 [==============================] - 0s 13ms/sample - loss: 0.5773 - accuracy: 1.0000 - val_loss: 2.5870 - val_accuracy: 0.0000e+00
# Epoch 3/30
# 8/8 [==============================] - 0s 13ms/sample - loss: 0.2161 - accuracy: 1.0000 - val_loss: 3.0159 - val_accuracy: 0.0000e+00
# Epoch 4/30
# 8/8 [==============================] - 0s 14ms/sample - loss: 0.1529 - accuracy: 1.0000 - val_loss: 3.3150 - val_accuracy: 0.0000e+00
# Epoch 5/30
# 8/8 [==============================] - 0s 13ms/sample - loss: 0.1404 - accuracy: 1.0000 - val_loss: 3.5361 - val_accuracy: 0.0000e+00
# 2/2 [==============================] - 0s 5ms/sample - loss: 3.5361 - accuracy: 0.0000e+00
#
# Test loss: 3.536073923110962, test accuracy: 0.0%
# Iteration : 6
# Processing dataset with fold6 for testing
#
# Model: "sequential_38"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_75 (Conv2D)           (None, 42, 34, 128)       3584
# _________________________________________________________________
# batch_normalization_73 (Batc (None, 42, 34, 128)       512
# _________________________________________________________________
# max_pooling2d_73 (MaxPooling (None, 21, 17, 128)       0
# _________________________________________________________________
# conv2d_76 (Conv2D)           (None, 19, 15, 128)       147584
# _________________________________________________________________
# batch_normalization_74 (Batc (None, 19, 15, 128)       512
# _________________________________________________________________
# max_pooling2d_74 (MaxPooling (None, 10, 8, 128)        0
# _________________________________________________________________
# flatten_36 (Flatten)         (None, 10240)             0
# _________________________________________________________________
# dense_72 (Dense)             (None, 64)                655424
# _________________________________________________________________
# dense_73 (Dense)             (None, 10)                650
# =================================================================
# Total params: 808,266
# Trainable params: 807,754
# Non-trainable params: 512
# _________________________________________________________________
# Train on 8 samples, validate on 2 samples
# Epoch 1/30
# 8/8 [==============================] - 2s 238ms/sample - loss: 6.9816 - accuracy: 0.1250 - val_loss: 14.0347 - val_accuracy: 0.0000e+00
# Epoch 2/30
# 8/8 [==============================] - 0s 13ms/sample - loss: 3.1112 - accuracy: 0.3750 - val_loss: 10.7279 - val_accuracy: 0.0000e+00
# Epoch 3/30
# 8/8 [==============================] - 0s 13ms/sample - loss: 1.0461 - accuracy: 0.6250 - val_loss: 7.6374 - val_accuracy: 0.0000e+00
# Epoch 4/30
# 8/8 [==============================] - 0s 13ms/sample - loss: 0.3912 - accuracy: 1.0000 - val_loss: 5.2365 - val_accuracy: 0.0000e+00
# Epoch 5/30
# 8/8 [==============================] - 0s 13ms/sample - loss: 0.2567 - accuracy: 1.0000 - val_loss: 3.4021 - val_accuracy: 0.0000e+00
# Epoch 6/30
# 8/8 [==============================] - 0s 14ms/sample - loss: 0.2081 - accuracy: 1.0000 - val_loss: 2.1162 - val_accuracy: 0.0000e+00
# Epoch 7/30
# 8/8 [==============================] - 0s 13ms/sample - loss: 0.1804 - accuracy: 1.0000 - val_loss: 1.2965 - val_accuracy: 0.5000
# 2/2 [==============================] - 0s 6ms/sample - loss: 1.2965 - accuracy: 0.5000
#
# Test loss: 1.2965292930603027, test accuracy: 50.0%
# Iteration : 7
# Processing dataset with fold7 for testing
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-217-44dd456674f2> in <module>
#      24     X_train, y_train, X_validation, y_validation, X_test, y_test = prepare_dataset(p,
#      25                                                                                    validation=False,
# ---> 26                                                                                    validation_size=0.3)
#      27
#      28
#
# <ipython-input-191-e23f2be556b1> in prepare_dataset(test_reference_idx, validation, validation_size)
#      13                       axis=-1)
#      14
# ---> 15     X_test = np.stack((np.rollaxis(np.dstack(test_data['MFCCs'].to_list()),-1),
#      16                        np.rollaxis(np.dstack(test_data['Chroma'].to_list()),-1),
#      17                        np.rollaxis(np.dstack(test_data['Tonnetz'].to_list()),-1)),
#
# <__array_function__ internals> in dstack(*args, **kwargs)
#
# ~/.conda/envs/TENSORFLOW/lib/python3.6/site-packages/numpy/lib/shape_base.py in dstack(tup)
#     719     if not isinstance(arrs, list):
#     720         arrs = [arrs]
# --> 721     return _nx.concatenate(arrs, 2)
#     722
#     723
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: need at least one array to concatenate

# %%
print(f"After 10 fold cross validation, average resulting accuracy is: {100*np.mean(test_acc)} percent")
# Out:
# After 10 fold cross validation, average resulting accuracy is: 20.0 percent

# %% [markdown]
# ## Conclusion

# %% [markdown]
# In order to further increment the accuracy (especially if proper routine is performed, i.e considering validation prior to testing) it is necessary to segment the original audio samples such that, each excerpt has the same length as it is already happening in the code above, but with a more delicate way to adjust the signal lengths:
# thus this means that at least short signals should be zero padded while long signal should be segmented first and most probably further partially zero padded later (and not only one of the two cases!).
#
# Also, beside hyperparameter tweaking and optimization, some more preliminary analysis (especially regarding the time length variation in time of this signals for the above mentioned issue) and different feature extraction (such as zero crossing, envelopes) might come into great help.
